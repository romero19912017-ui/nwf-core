# %% [markdown]
# # Calibration Demo
#
# AgreementRatio, PlattScaler, reliability diagram, ECE.

# %%
# %run ../examples/calibration_demo.py

# %% [markdown]
# Or run: `python examples/calibration_demo.py --save results/cal.png`

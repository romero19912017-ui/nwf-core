# %% [markdown]
# # OOD Detection via Potential
#
# Synthetic 2D data: in-distribution vs OOD, histograms, ROC, AUC.

# %%
# %run ../examples/potential_ood.py

# %% [markdown]
# Or run: `python examples/potential_ood.py --save results/ood.png`

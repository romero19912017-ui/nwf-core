# %% [markdown]
# # Weighted charges (axiom 4)
#
# Alpha in potential and weighted k-NN voting. Class A alpha=2, B alpha=1.

# %%
# %run ../examples/weighted_demo.py

# %% [markdown]
# Or: `python examples/weighted_demo.py --save results/weighted.png`
